# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
from tensorflow.keras.datasets import fashion_mnist
(x_train,x_lab),(y_test,y_lab)=fashion_mnist.load_data()
plt.imshow(x_train[0])
plt.title('Class: {}'.format(x_lab[0]))
plt.figure()

# %%
x_train=keras.utils.normalize(x_train,axis=1)
y_test=keras.utils.normalize(y_test,axis=1)
plt.imshow(x_train[0])

plt.title('Class: {}'.format(x_lab[0]))
plt.figure()

# %%
model = Sequential()
model.add(Flatten(input_shape=((28,28))))
model.add(Dense(200, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.compile(optimizer = "adam", loss="sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
model.evaluate(y_test, y_lab)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.2998 - accuracy: 0.1165
# [2.2998032569885254, 0.11649999767541885]

# %%
p = model.predict(y_test[:10])
print(p)
# Out:
# [[0.1053829  0.10947199 0.0924747  0.07340328 0.12735161 0.08669434
#   0.07848109 0.12356865 0.10526305 0.09790836]
#  [0.08698747 0.10816163 0.11512594 0.08401822 0.10004245 0.08818292
#   0.09058575 0.0930104  0.09702634 0.13685891]
#  [0.10963027 0.11075152 0.10298941 0.09771962 0.09733231 0.09399202
#   0.08169806 0.11727592 0.07852729 0.11008368]
#  [0.12254319 0.11935671 0.09399328 0.10016509 0.08876903 0.09127547
#   0.08431549 0.08812656 0.0930369  0.11841827]
#  [0.0940932  0.09789056 0.10743941 0.08510074 0.12308416 0.09171674
#   0.08092625 0.10668106 0.09399531 0.11907255]
#  [0.10456149 0.1077945  0.0989859  0.10156567 0.10747838 0.09431784
#   0.08338226 0.10225543 0.0893302  0.11032835]
#  [0.10400289 0.11944535 0.09259992 0.08967838 0.11711919 0.0772578
#   0.08773997 0.1035124  0.08750634 0.12113785]
#  [0.08884399 0.10860553 0.10361101 0.07826254 0.09928241 0.0929292
#   0.08889221 0.12996733 0.0882265  0.12137934]
#  [0.12616    0.10160707 0.09332383 0.11398707 0.09823988 0.08919106
#   0.07555674 0.1131756  0.0904609  0.09829795]
#  [0.11459258 0.10564547 0.09702318 0.09331726 0.10804534 0.08537377
#   0.08017983 0.14552286 0.07525005 0.09504961]]

# %%
pred = np.argmax(p, axis=1)
print(pred)
print(y_lab[:10])
# Out:
# [4 9 7 0 4 9 9 7 0 7]
# [9 2 1 1 6 1 4 6 5 7]

# %%
for i in range(10):
  plt.imshow(y_test[i], cmap="binary")
  plt.title('Original: {}, Predicted: {}'.format(y_lab[i], pred[i]))
  plt.axis("Off")
  plt.figure()
